# %%
from IPython.display import display, HTML
import spot
spot.setup(size='5,4')

# %% [markdown]
# This shows the effect of running `cleanup_acceptance()` on 10 randomly generated automata.

# %%
txt = "<TABLE><TR><TH>before</TH><TH>after</TH>"
for a in spot.automata('randaut -A "random 4" -H -Q5 -n10 2|'):
    txt += "<TR><TD>{0}</TD><TD>{1}</TD></TR>".format(a.show('.a').data, spot.cleanup_acceptance(a).show('.a').data)
txt += ("</TABLE>")
HTML(txt)
# Out:
# <TABLE><TR><TH>before</TH><TH>after</TH><TR><TD><svg height="91pt" viewBox="0.00 0.00 360.00 90.55" width="360pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g class="graph" id="graph0" transform="scale(.602 .602) rotate(0) translate(4 146.4079)">
# <polygon fill="#ffffff" points="-4,4 -4,-146.4079 594,-146.4079 594,4 -4,4" stroke="transparent"/>
# <text fill="#000000" font-family="Lato" font-size="14.00" text-anchor="start" x="179" y="-128.2079">Fin(</text>
# <text fill="#ff4da0" font-family="Lato" font-size="14.00" text-anchor="start" x="204" y="-128.2079">❶</text>
# <text fill="#000000" font-family="Lato" font-size="14.00" text-anchor="start" x="220" y="-128.2079">) | (Fin(</text>
# <text fill="#ff7f00" font-family="Lato" font-size="14.00" text-anchor="start" x="263" y="-128.2079">❷</text>
# <text fill="#000000" font-family="Lato" font-size="14.00" text-anchor="start" x="279" y="-128.2079">) &amp; Fin(</text>
# <text fill="#6a3d9a" font-family="Lato" font-size="14.00" text-anchor="start" x="325" y="-128.2079">❸</text>
# <text fill="#000000" font-family="Lato" font-size="14.00" text-anchor="start" x="341" y="-128.2079">) &amp; Fin(</text>
# <text fill="#1f78b4" font-family="Lato" font-size="14.00" text-anchor="start" x="387" y="-128.2079">⓿</text>
# <text fill="#000000" font-family="Lato" font-size="14.00" text-anchor="start" x="403" y="-128.2079">))</text>
# <!-- I -->
# <!-- 0 -->
# <g class="node" id="node2">
# <title>0</title>
# <ellipse cx="56" cy="-40.4079" fill="#ffffaa" rx="18" ry="18" stroke="#000000"/>
# <text fill="#000000" font-family="Lato" font-size="14.00" text-anchor="middle" x="56" y="-36.7079">0</text>
# </g>
# <!-- I&#45;&gt;0 -->
# <g class="edge" id="edge1">
# <title>I-&gt;0</title>
# <path d="M1.1233,-40.4079C4.178,-40.4079 17.9448,-40.4079 30.9241,-40.4079" fill="none" stroke="#000000"/>
# <polygon fill="#000000" points="37.9807,-40.4079 30.9808,-43.558 34.4807,-40.408 30.9807,-40.408 30.9807,-40.408 30.9807,-40.408 34.4807,-40.408 30.9807,-37.258 37.9807,-40.4079 37.9807,-40.4079" stroke="#000000"/>
# </g>
# <!-- 4 -->
# <g class="node" id="node3">
# <title>4</title>
# <ellipse cx="183" cy="-53.4079" fill="#ffffaa" rx="18" ry="18" stroke="#000000"/>
# <text fill="#000000" font-family="Lato" font-size="14.00" text-anchor="middle" x="183" y="-49.7079">4</text>
# </g>
# <!-- 0&#45;&gt;4 -->
# <g class="edge" id="edge2">
# <title>0-&gt;4</title>
# <path d="M68.3193,-53.8578C74.7225,-59.8506 83.0689,-66.2581 92,-69.4079 115.0528,-77.5382 123.0881,-74.4824 147,-69.4079 151.4784,-68.4575 156.0762,-66.9102 160.4246,-65.1432" fill="none" stroke="#000000"/>
# <polygon fill="#000000" points="166.9997,-62.2397 161.8688,-67.949 163.798,-63.6536 160.5963,-65.0674 160.5963,-65.0674 160.5963,-65.0674 163.798,-63.6536 159.3238,-62.1859 166.9997,-62.2397 166.9997,-62.2397" stroke="#000000"/>
# <text fill="#000000" font-family="Lato" font-size="14.00" text-anchor="start" x="92" y="-78.2079">!p0 &amp; p1</text>
# </g>
# <!-- 4&#45;&gt;0 -->
# <g class="edge" id="edge8">
# <title>4-&gt;0</title>
# <path d="M166.9997,-44.5762C160.9256,-41.6903 153.8243,-38.8561 147,-37.4079 125.0222,-32.7439 99.3977,-34.1836 80.9506,-36.3871" fill="none" stroke="#000000"/>
# <polygon fill="#000000" points="74.0092,-37.2925 80.5429,-33.2635 77.4798,-36.8398 80.9504,-36.3871 80.9504,-36.3871 80.9504,-36.3871 77.4798,-36.8398 81.3578,-39.5106 74.0092,-37.2925 74.0092,-37.2925" stroke="#000000"/>
# <text fill="#000000" font-family="Lato" font-size="14.00" text-anchor="start" x="92" y="-55.2079">!p0 &amp; p1</text>
# <text fill="#1f78b4" font-family="Lato" font-size="14.00" text-anchor="start" x="103.5" y="-41.2079">⓿</text>
# <text fill="#ff7f00" font-family="Lato" font-size="14.00" text-anchor="start" x="119.5" y="-41.2079">❷</text>
# </g>
# <!-- 4&#45;&gt;4 -->
# <g class="edge" id="edge9">
# <title>4-&gt;4</title>
# <path d="M172.6266,-68.1996C169.2492,-78.8244 172.707,-89.4079 183,-89.4079 190.8806,-89.4079 194.7545,-83.2041 194.6217,-75.5276" fill="none" stroke="#000000"/>
# <polygon fill="#000000" points="193.3734,-68.1996 197.6542,-74.5712 193.9612,-71.6499 194.549,-75.1002 194.549,-75.1002 194.549,-75.1002 193.9612,-71.6499 191.4437,-75.6292 193.3734,-68.1996 193.3734,-68.1996" stroke="#000000"/>
# <text fill="#000000" font-family="Lato" font-size="14.00" text-anchor="start" x="155.5" y="-93.2079">!p0 &amp; p1</text>
# </g>
# <!-- 3 -->
# <g class="node" id="node6">
# <title>3</title>
# <ellipse cx="314" cy="-53.4079" fill="#ffffaa" rx="18" ry="18" stroke="#000000"/>
# <text fill="#000000" font-family="Lato" font-size="14.00" text-anchor="middle" x="314" y="-49.7079">3</text>
# </g>
# <!-- 4&#45;&gt;3 -->
# <g class="edge" id="edge10">
# <title>4-&gt;3</title>
# <path d="M201.215,-53.4079C223.9943,-53.4079 263.1115,-53.4079 288.765,-53.4079" fill="none" stroke="#000000"/>
# <polygon fill="#000000" points="295.9397,-53.4079 288.9398,-56.558 292.4397,-53.408 288.9397,-53.408 288.9397,-53.408 288.9397,-53.408 292.4397,-53.408 288.9397,-50.258 295.9397,-53.4079 295.9397,-53.4079" stroke="#000000"/>
# <text fill="#000000" font-family="Lato" font-size="14.00" text-anchor="start" x="219" y="-57.2079">!p0 &amp; !p1</text>
# </g>
# <!-- 1 -->
# <g class="node" id="node4">
# <title>1</title>
# <ellipse cx="445" cy="-23.4079" fill="#ffffaa" rx="18" ry="18" stroke="#000000"/>
# <text fill="#000000" font-family="Lato" font-size="14.00" text-anchor="middle" x="445" y="-19.7079">1</text>
# </g>
# <!-- 1&#45;&gt;0 -->
# <g class="edge" id="edge3">
# <title>1-&gt;0</title>
# <path d="M426.9799,-23.4115C382.4951,-23.4617 263.8961,-23.8466 165,-26.4079 132.5391,-27.2486 124.0103,-23.9524 92,-29.4079 88.0541,-30.0804 83.9355,-31.0608 79.9528,-32.1633" fill="none" stroke="#000000"/>
# <polygon fill="#000000" points="72.9974,-34.2394 78.804,-29.2188 76.3512,-33.2383 79.705,-32.2372 79.705,-32.2372 79.705,-32.2372 76.3512,-33.2383 80.606,-35.2556 72.9974,-34.2394 72.9974,-34.2394" stroke="#000000"/>
# <text fill="#000000" font-family="Lato" font-size="14.00" text-anchor="start" x="222.5" y="-28.2079">p0 &amp; p1</text>
# </g>
# <!-- 2 -->
# <g class="node" id="node5">
# <title>2</title>
# <ellipse cx="572" cy="-23.4079" fill="#ffffaa" rx="18" ry="18" stroke="#000000"/>
# <text fill="#000000" font-family="Lato" font-size="14.00" text-anchor="middle" x="572" y="-19.7079">2</text>
# </g>
# <!-- 1&#45;&gt;2 -->
# <g class="edge" id="edge4">
# <title>1-&gt;2</title>
# <path d="M463.196,-23.4079C485.0753,-23.4079 521.9273,-23.4079 546.6013,-23.4079" fill="none" stroke="#000000"/>
# <polygon fill="#000000" points="553.8378,-23.4079 546.8378,-26.558 550.3378,-23.408 546.8378,-23.408 546.8378,-23.408 546.8378,-23.408 550.3378,-23.408 546.8377,-20.258 553.8378,-23.4079 553.8378,-23.4079" stroke="#000000"/>
# <text fill="#000000" font-family="Lato" font-size="14.00" text-anchor="start" x="481" y="-41.2079">p0 &amp; !p1</text>
# <text fill="#1f78b4" font-family="Lato" font-size="14.00" text-anchor="start" x="492.5" y="-27.2079">⓿</text>
# <text fill="#6a3d9a" font-family="Lato" font-size="14.00" text-anchor="start" x="508.5" y="-27.2079">❸</text>
# </g>
# <!-- 2&#45;&gt;1 -->
# <g class="edge" id="edge5">
# <title>2-&gt;1</title>
# <path d="M556.8943,-13.3379C550.6932,-9.7761 543.2713,-6.209 536,-4.4079 512.2726,1.4693 504.7274,1.4693 481,-4.4079 476.1146,-5.618 471.1612,-7.6253 466.5558,-9.8926" fill="none" stroke="#000000"/>
# <polygon fill="#000000" points="460.1057,-13.3379 464.7959,-7.2613 463.1929,-11.6889 466.2801,-10.0398 466.2801,-10.0398 466.2801,-10.0398 463.1929,-11.6889 467.7642,-12.8183 460.1057,-13.3379 460.1057,-13.3379" stroke="#000000"/>
# <text fill="#000000" font-family="Lato" font-size="14.00" text-anchor="start" x="481" y="-8.2079">!p0 &amp; p1</text>
# </g>
# <!-- 3&#45;&gt;1 -->
# <g class="edge" id="edge7">
# <title>3-&gt;1</title>
# <path d="M331.6672,-49.362C354.5209,-44.1283 394.4565,-34.9828 420.3036,-29.0636" fill="none" stroke="#000000"/>
# <polygon fill="#000000" points="427.1943,-27.4856 421.0741,-32.1188 423.7826,-28.2669 420.3709,-29.0482 420.3709,-29.0482 420.3709,-29.0482 423.7826,-28.2669 419.6677,-25.9777 427.1943,-27.4856
